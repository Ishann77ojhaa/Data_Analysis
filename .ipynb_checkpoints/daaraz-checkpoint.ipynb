# %%
import pandas as pd

# %%
dd = pd.read_csv("datasets/daraz_dataset.csv")
print(dd)
# Out:
#       OrderID   OrderDate    CustomerName  Age  Gender   District  \
# 0    DZ100001  2026-03-04    Anita Basnet   24    Male  Nepalgunj
# 1    DZ100002  2026-01-07    Pooja Basnet   52  Female    Pokhara
# 2    DZ100003  2026-03-29    Rohit Basnet   31  Female   Lalitpur
# 3    DZ100004  2026-04-28    Pooja Sharma   42    Male    Chitwan
# 4    DZ100005  2026-03-16    Ram Adhikari   32    Male     Dharan
# ..        ...         ...             ...  ...     ...        ...
# 495  DZ100496  2026-03-08      Sita Thapa   48    Male  Nepalgunj
# 496  DZ100497  2026-05-10    Ram Adhikari   35  Female  Bhaktapur
# 497  DZ100498  2026-06-04  Nabin Shrestha   27  Female    Itahari
# 498  DZ100499  2026-01-22   Gita Shrestha   27  Female     Dharan
# 499  DZ100500  2026-01-14  Rohit Adhikari   25    Male  Bhaktapur
#
#         Category            Product  Quantity  UnitPrice  DiscountPercent  \
# 0         Sports           Football         1      48898               10
# ...

# %%
print(dd["TotalAmount"].max())  #max money ordered
print(dd["TotalAmount"].min())  #min money ordered
print(dd["TotalAmount"].mean()) #average money ordered
# Out:
# 229910.0
# 478.8
# 70063.721

# %%
print(dd[["CustomerName", "District", "TotalAmount"]])
# Out:
#        CustomerName   District  TotalAmount
# 0      Anita Basnet  Nepalgunj     44008.20
# 1      Pooja Basnet    Pokhara     53468.80
# 2      Rohit Basnet   Lalitpur     78290.10
# 3      Pooja Sharma    Chitwan     88175.00
# 4      Ram Adhikari     Dharan      3137.85
# ..              ...        ...          ...
# 495      Sita Thapa  Nepalgunj    115060.80
# 496    Ram Adhikari  Bhaktapur     21686.60
# 497  Nabin Shrestha    Itahari     48890.00
# 498   Gita Shrestha     Dharan     11106.00
# 499  Rohit Adhikari  Bhaktapur     68693.40
#
# [500 rows x 3 columns]

# %%
print(dd.iloc[11])  # 11 index data will come
# Out:
# OrderID                    DZ100012
# OrderDate                2026-02-09
# CustomerName         Kiran Adhikari
# Age                              28
# Gender                         Male
# District                  Nepalgunj
# Category                      Books
# Product            Data Science 101
# Quantity                          5
# UnitPrice                     40209
# DiscountPercent                   5
# TotalAmount               190992.75
# PaymentMethod                   COD
# Rating                            4
# OrderStatus               Delivered
# Name: 11, dtype: object

# %%
print(dd.iloc[0:5]) # 0 to 4 index data will come.
# Out:
#     OrderID   OrderDate  CustomerName  Age  Gender   District     Category  \
# 0  DZ100001  2026-03-04  Anita Basnet   24    Male  Nepalgunj       Sports
# 1  DZ100002  2026-01-07  Pooja Basnet   52  Female    Pokhara  Electronics
# 2  DZ100003  2026-03-29  Rohit Basnet   31  Female   Lalitpur        Books
# 3  DZ100004  2026-04-28  Pooja Sharma   42    Male    Chitwan         Home
# 4  DZ100005  2026-03-16  Ram Adhikari   32    Male     Dharan    Groceries
#
#              Product  Quantity  UnitPrice  DiscountPercent  TotalAmount  \
# 0           Football         1      48898               10     44008.20
# 1  Bluetooth Speaker         2      33418               20     53468.80
# 2      Python Basics         2      46053               15     78290.10
# 3              Chair         5      17635                0     88175.00
# 4                Tea         1       3303                5      3137.85
#
#   PaymentMethod  Rating OrderStatus
# 0       IME Pay       1   Delivered
# ...

# %%
print(dd.iloc[0,2])
# Out:
# Anita Basnet

# %%
print(dd.iloc[:,2])
# Out:
# 0        Anita Basnet
# 1        Pooja Basnet
# 2        Rohit Basnet
# 3        Pooja Sharma
# 4        Ram Adhikari
#             ...
# 495        Sita Thapa
# 496      Ram Adhikari
# 497    Nabin Shrestha
# 498     Gita Shrestha
# 499    Rohit Adhikari
# Name: CustomerName, Length: 500, dtype: str

# %%
print(dd.iloc[:,[0,1,2,3,4]])
# Out:
#       OrderID   OrderDate    CustomerName  Age  Gender
# 0    DZ100001  2026-03-04    Anita Basnet   24    Male
# 1    DZ100002  2026-01-07    Pooja Basnet   52  Female
# 2    DZ100003  2026-03-29    Rohit Basnet   31  Female
# 3    DZ100004  2026-04-28    Pooja Sharma   42    Male
# 4    DZ100005  2026-03-16    Ram Adhikari   32    Male
# ..        ...         ...             ...  ...     ...
# 495  DZ100496  2026-03-08      Sita Thapa   48    Male
# 496  DZ100497  2026-05-10    Ram Adhikari   35  Female
# 497  DZ100498  2026-06-04  Nabin Shrestha   27  Female
# 498  DZ100499  2026-01-22   Gita Shrestha   27  Female
# 499  DZ100500  2026-01-14  Rohit Adhikari   25    Male
#
# [500 rows x 5 columns]

# %%
print(dd.iloc[-1])
# Out:
# OrderID                  DZ100500
# OrderDate              2026-01-14
# CustomerName       Rohit Adhikari
# Age                            25
# Gender                       Male
# District                Bhaktapur
# Category                   Sports
# Product                  Yoga Mat
# Quantity                        2
# UnitPrice                   38163
# DiscountPercent                10
# TotalAmount               68693.4
# PaymentMethod             IME Pay
# Rating                          4
# OrderStatus              Returned
# Name: 499, dtype: object

# %%
print(dd.iloc[0:3, 0:5])
# Out:
#     OrderID   OrderDate  CustomerName  Age  Gender
# 0  DZ100001  2026-03-04  Anita Basnet   24    Male
# 1  DZ100002  2026-01-07  Pooja Basnet   52  Female
# 2  DZ100003  2026-03-29  Rohit Basnet   31  Female

# %%
print(dd.loc[:,["CustomerName", "District"]])
# Out:
#        CustomerName   District
# 0      Anita Basnet  Nepalgunj
# 1      Pooja Basnet    Pokhara
# 2      Rohit Basnet   Lalitpur
# 3      Pooja Sharma    Chitwan
# 4      Ram Adhikari     Dharan
# ..              ...        ...
# 495      Sita Thapa  Nepalgunj
# 496    Ram Adhikari  Bhaktapur
# 497  Nabin Shrestha    Itahari
# 498   Gita Shrestha     Dharan
# 499  Rohit Adhikari  Bhaktapur
#
# [500 rows x 2 columns]

# %%
print(dd.loc[dd["District"] == "Kathmandu"])
# Out:
#       OrderID   OrderDate      CustomerName  Age  Gender   District  \
# 28   DZ100029  2026-05-30      Pooja Basnet   45    Male  Kathmandu
# 30   DZ100031  2026-03-10    Nabin Adhikari   24  Female  Kathmandu
# 39   DZ100040  2026-01-28     Manish Basnet   29  Female  Kathmandu
# 63   DZ100064  2026-04-15      Sabina Thapa   48  Female  Kathmandu
# 104  DZ100105  2026-02-10         Kiran Rai   38    Male  Kathmandu
# 109  DZ100110  2026-04-14        Manish Rai   25  Female  Kathmandu
# 127  DZ100128  2026-06-30       Suman Karki   18    Male  Kathmandu
# 133  DZ100134  2026-01-10      Sneha Basnet   20    Male  Kathmandu
# 147  DZ100148  2026-02-09       Nabin Thapa   39    Male  Kathmandu
# 160  DZ100161  2026-01-09      Roshan Thapa   25    Male  Kathmandu
# 175  DZ100176  2026-06-30      Kiran Sharma   54    Male  Kathmandu
# 177  DZ100178  2026-05-25     Sita Shrestha   47  Female  Kathmandu
# 181  DZ100182  2026-03-30          Gita Rai   30    Male  Kathmandu
# ...

# %%
print(dd.loc[dd["TotalAmount"] > 30000])
# Out:
#       OrderID   OrderDate    CustomerName  Age  Gender   District  \
# 0    DZ100001  2026-03-04    Anita Basnet   24    Male  Nepalgunj
# 1    DZ100002  2026-01-07    Pooja Basnet   52  Female    Pokhara
# 2    DZ100003  2026-03-29    Rohit Basnet   31  Female   Lalitpur
# 3    DZ100004  2026-04-28    Pooja Sharma   42    Male    Chitwan
# 5    DZ100006  2026-06-29    Ram Shrestha   28    Male  Bhaktapur
# ..        ...         ...             ...  ...     ...        ...
# 490  DZ100491  2026-04-27    Binita Karki   29  Female    Chitwan
# 494  DZ100495  2026-05-01    Roshan Thapa   39  Female    Itahari
# 495  DZ100496  2026-03-08      Sita Thapa   48    Male  Nepalgunj
# 497  DZ100498  2026-06-04  Nabin Shrestha   27  Female    Itahari
# 499  DZ100500  2026-01-14  Rohit Adhikari   25    Male  Bhaktapur
#
#         Category            Product  Quantity  UnitPrice  DiscountPercent  \
# 0         Sports           Football         1      48898               10
# ...

# %%
# Chaining or filter :- district Ktm and payment method esewa
print(dd[(dd["District"] == "Kathmandu") & (dd["PaymentMethod"] == "eSewa")])
# Out:
#       OrderID   OrderDate   CustomerName  Age  Gender   District     Category  \
# 147  DZ100148  2026-02-09    Nabin Thapa   39    Male  Kathmandu  Electronics
# 193  DZ100194  2026-06-14  Sita Shrestha   20    Male  Kathmandu      Fashion
# 234  DZ100235  2026-05-28  Gita Shrestha   49  Female  Kathmandu         Home
# 269  DZ100270  2026-05-07      Pooja Rai   29  Female  Kathmandu    Groceries
# 460  DZ100461  2026-05-27   Pooja Basnet   47  Female  Kathmandu      Fashion
#
#          Product  Quantity  UnitPrice  DiscountPercent  TotalAmount  \
# 147  Smart Watch         2      39084               20      62534.4
# 193       Jacket         4      12361               20      39555.2
# 234        Chair         3      22435               20      53844.0
# 269     Biscuits         2      37203                5      70685.7
# 460     Sneakers         3      40348               20      96835.2
#
#     PaymentMethod  Rating OrderStatus
# 147         eSewa       1  Processing
# ...

# %%
#category = electronics and rating = 5 stars
print(dd[(dd["Category"] == "Electronics") & (dd["Rating"] == 5)])
# Out:
#       OrderID   OrderDate     CustomerName  Age  Gender    District  \
# 1    DZ100002  2026-01-07     Pooja Basnet   52  Female     Pokhara
# 57   DZ100058  2026-06-26     Nabin Basnet   31  Female  Biratnagar
# 97   DZ100098  2026-02-02   Rohit Shrestha   55  Female      Dharan
# 180  DZ100181  2026-02-02   Anita Adhikari   18    Male  Biratnagar
# 205  DZ100206  2026-05-23     Ramesh Karki   24    Male    Lalitpur
# 271  DZ100272  2026-01-29  Ramesh Adhikari   41    Male     Itahari
# 280  DZ100281  2026-02-09         Sita Rai   18  Female    Lalitpur
# 324  DZ100325  2026-05-08     Aarav Sharma   43  Female   Kathmandu
# 329  DZ100330  2026-05-10       Gita Karki   18    Male     Chitwan
# 355  DZ100356  2026-02-05     Pooja Basnet   34    Male    Lalitpur
# 377  DZ100378  2026-02-21       Ramesh Rai   30    Male   Nepalgunj
# 387  DZ100388  2026-01-09       Ramesh Rai   43    Male      Butwal
# 395  DZ100396  2026-06-11    Gita Adhikari   28  Female      Dharan
# ...

# %%
print(dd.sort_values("TotalAmount", ascending=False))
# Out:
#       OrderID   OrderDate     CustomerName  Age  Gender    District  \
# 375  DZ100376  2026-02-11       Asha Thapa   18    Male   Bhaktapur
# 271  DZ100272  2026-01-29  Ramesh Adhikari   41    Male     Itahari
# 132  DZ100133  2026-02-04         Sita Rai   52  Female   Bhaktapur
# 435  DZ100436  2026-03-20        Nabin Rai   46    Male      Butwal
# 472  DZ100473  2026-02-22       Sita Karki   42    Male   Kathmandu
# ..        ...         ...              ...  ...     ...         ...
# 94   DZ100095  2026-03-02       Roshan Rai   19    Male  Biratnagar
# 492  DZ100493  2026-05-04     Kiran Sharma   55  Female    Lalitpur
# 74   DZ100075  2026-03-18  Roshan Shrestha   49    Male      Butwal
# 195  DZ100196  2026-05-22    Manish Sharma   19  Female     Chitwan
# 27   DZ100028  2026-02-03     Rohit Basnet   46  Female     Chitwan
#
#         Category            Product  Quantity  UnitPrice  DiscountPercent  \
# 375        Books           Notebook         5      45982                0
# ...
