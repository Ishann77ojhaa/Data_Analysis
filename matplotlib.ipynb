# %%
pip install matplotlib
# Out:
# ...
#   Using cached contourpy-1.3.3-cp313-cp313-win_amd64.whl.metadata (5.5 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached kiwisolver-1.5.0-cp313-cp313-win_amd64.whl.metadata (5.2 kB)
# ...
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# ...
#    ---------------------------------------- 0.0/9.3 MB ? eta -:--:--
#    ------------ --------------------------- 2.9/9.3 MB 16.1 MB/s eta 0:00:01
#    ------------------------------- -------- 7.3/9.3 MB 19.3 MB/s eta 0:00:01
#    ---------------------------------------- 9.3/9.3 MB 15.4 MB/s eta 0:00:00
# Using cached contourpy-1.3.3-cp313-cp313-win_amd64.whl (226 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# ...
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 2.3/2.3 MB 12.1 MB/s eta 0:00:00
# Using cached kiwisolver-1.5.0-cp313-cp313-win_amd64.whl (73 kB)
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
fruits = ['Apple', 'Banana', 'Orange']
sales = [100, 150, 80]
revenue = [20,30,40]

#Line chart
plt.Figure(figsize=(6,8)) #pixels 
plt.plot(sales, revenue,c = 'red', marker='o')
plt.xlabel("Sales")
plt.ylabel("Revenue")
plt.title("Fruit Sales")
plt.show()

# %%
dd = pd.read_csv("datasets/daraz_dataset.csv")

# %%
category = dd.groupby("Category")["Product"].count()
category.index
category.values
# Out:
# array([58, 78, 73, 64, 75, 81, 71])

# %%
#Bar chart

plt.figure(figsize=(10,6))
plt.bar(category.index, category.values, color = "green", edgecolor = "black")
plt.xlabel("Categories", fontsize = 20)
plt.ylabel("Total Products", fontsize = 20)
plt.title("Products according to category",fontsize = 20)
plt.grid(axis = "y", linestyle = "--", alpha = 0.5)
plt.show()

# %%
category
# Out:
# Category
# Beauty         58
# Books          78
# Electronics    73
# Fashion        64
# Groceries      75
# Home           81
# Sports         71
# Name: Product, dtype: int64

# %%
#Pie Chart

colors = ['#ff9999', '#66b3ff', '#99ff99', '#ffcc99', '#c2c2f0' , 'grey', 'yellow']  #for custom colors
explode = (0.1, 0, 0, 0, 0,0,0) #for little highlight
plt.figure(figsize=(12, 6))  #for increasing size
plt.pie(category.values, labels = category.index, colors = colors, shadow = True, explode=explode)
plt.title("Category Breakdown")
plt.show()

# %%
gender = dd.groupby("Gender")["Product"].count()
gender
# Out:
# Gender
# Female    256
# Male      244
# Name: Product, dtype: int64

# %%
plt.pie(gender.values, labels = gender.index, shadow = True)
plt.title("Clssification acc to gender")
# Out:
# Text(0.5, 1.0, 'Clssification acc to gender')

# %%
#Histogram

# bins = [0,5000,10000,20000,50000,80000]
plt.hist(dd["UnitPrice"], color = "skyblue", edgecolor = "black", alpha = 0.8, bins = 8)  #arguments are all same as bar graph

# Add labels and title
plt.xlabel('Unit-Price')
plt.ylabel('Frequency')
plt.title('Basic Histogram Example')

# Display the plot
plt.show()

# %%
dd
# Out:
#       OrderID   OrderDate    CustomerName  Age  Gender   District  \
# 0    DZ100001  2026-03-04    Anita Basnet   24    Male  Nepalgunj
# 1    DZ100002  2026-01-07    Pooja Basnet   52  Female    Pokhara
# 2    DZ100003  2026-03-29    Rohit Basnet   31  Female   Lalitpur
# 3    DZ100004  2026-04-28    Pooja Sharma   42    Male    Chitwan
# 4    DZ100005  2026-03-16    Ram Adhikari   32    Male     Dharan
# ..        ...         ...             ...  ...     ...        ...
# 495  DZ100496  2026-03-08      Sita Thapa   48    Male  Nepalgunj
# 496  DZ100497  2026-05-10    Ram Adhikari   35  Female  Bhaktapur
# 497  DZ100498  2026-06-04  Nabin Shrestha   27  Female    Itahari
# 498  DZ100499  2026-01-22   Gita Shrestha   27  Female     Dharan
# 499  DZ100500  2026-01-14  Rohit Adhikari   25    Male  Bhaktapur
#
#         Category            Product  Quantity  UnitPrice  DiscountPercent  \
# 0         Sports           Football         1      48898               10
# ...

# %%
#scatter plot

data = {
    "Age" : [20,22,24,26,28,30],
    "TotalAmount" : [1000,1200,1500,2000,3000,32000]
}

dfd = pd.DataFrame(data)

plt.scatter(dfd["Age"], dfd["TotalAmount"])
plt.xlabel("Age")
plt.ylabel("TotalAmount")
plt.grid(True)
plt.show()

# %%
dd
# Out:
#       OrderID   OrderDate    CustomerName  Age  Gender   District  \
# 0    DZ100001  2026-03-04    Anita Basnet   24    Male  Nepalgunj
# 1    DZ100002  2026-01-07    Pooja Basnet   52  Female    Pokhara
# 2    DZ100003  2026-03-29    Rohit Basnet   31  Female   Lalitpur
# 3    DZ100004  2026-04-28    Pooja Sharma   42    Male    Chitwan
# 4    DZ100005  2026-03-16    Ram Adhikari   32    Male     Dharan
# ..        ...         ...             ...  ...     ...        ...
# 495  DZ100496  2026-03-08      Sita Thapa   48    Male  Nepalgunj
# 496  DZ100497  2026-05-10    Ram Adhikari   35  Female  Bhaktapur
# 497  DZ100498  2026-06-04  Nabin Shrestha   27  Female    Itahari
# 498  DZ100499  2026-01-22   Gita Shrestha   27  Female     Dharan
# 499  DZ100500  2026-01-14  Rohit Adhikari   25    Male  Bhaktapur
#
#         Category            Product  Quantity  UnitPrice  DiscountPercent  \
# 0         Sports           Football         1      48898               10
# ...

# %%
#Relatiion between price and rating

plt.scatter(dd["UnitPrice"], dd["Rating"])
plt.xlabel("UnitPrice")
plt.ylabel("Rating")
plt.grid(True)
plt.show()

# %%
#Relation between age and total amount

plt.scatter(dd["Age"], dd["TotalAmount"])
plt.xlabel("Age")
plt.ylabel("TotalAmount")
plt.grid(True)
plt.title("Age vs Total amount")
plt.show()
