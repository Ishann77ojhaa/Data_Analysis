# %%
print("Hello Pandas")
# Out:
# Hello Pandas

# %%
import pandas as pd

print("Working..")
# Out:
# Working..

# %%
result = pd.Series(["Japan", "USA", "Nepal"])
print(result)
# Out:
# 0    Japan
# 1      USA
# 2    Nepal
# dtype: str

# %%
number_series = pd.Series([10,20,30], index = ["ek", "dui", "tin"])
print(number_series)
# Out:
# ek     10
# dui    20
# tin    30
# dtype: int64

# %%
print(number_series["dui"])
print(number_series["tin"])
# Out:
# 20
# 30

# %%
student_data = {
    "name" : ["Ishan", "shan", "han"],
    "age" : [21,22,23],
    "course" : ["ai_udaan", "mern", "reactjs"]
}
student_dataframe = pd.DataFrame(student_data)
print(student_dataframe)
# Out:
#     name  age    course
# 0  Ishan   21  ai_udaan
# 1   shan   22      mern
# 2    han   23   reactjs

# %%
student_datas = pd.read_csv("datasets/student_data.csv")
print(student_datas)
# Out:
#       study_hours  attendance  sleep_hours  internet_usage  \
# 0               7          56            8               7
# 1               4          69            5               3
# 2              11          60            7               6
# 3               8          99            9               8
# 4               5          52            8               6
# ...           ...         ...          ...             ...
# 9995            2          58            9               7
# 9996            7          98            6               9
# 9997           10          44            8               5
# 9998           10          75            7               5
# 9999            2          70            6              11
#
#       assignments_completed  previous_score  exam_score placement_status
# 0                        10              62      100.00           Placed
# 1                         8              56      100.00           Placed
# ...
