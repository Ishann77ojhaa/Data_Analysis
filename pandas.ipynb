# %%
print("Hello Pandas")
# Out:
# Hello Pandas

# %%
import pandas as pd

print("Working..")
# Out:
# Working..

# %%
result = pd.Series(["Japan", "USA", "Nepal"])  #Series is like a 1d array
print(result)
# Out:
# 0    Japan
# 1      USA
# 2    Nepal
# dtype: str

# %%
number_series = pd.Series([10,20,30], index = ["ek", "dui", "tin"])
print(number_series)
# Out:
# ek     10
# dui    20
# tin    30
# dtype: int64

# %%
print(number_series["dui"])
print(number_series["tin"])
# Out:
# 20
# 30

# %%
student_data = {
    "name" : ["Ishan", "shan", "han"],
    "age" : [21,22,23],
    "course" : ["ai_udaan", "mern", "reactjs"]
}
student_dataframe = pd.DataFrame(student_data)           #Dataframe is like 2d array
print(student_dataframe)
# Out:
#     name  age    course
# 0  Ishan   21  ai_udaan
# 1   shan   22      mern
# 2    han   23   reactjs

# %%
student_datas = pd.read_csv("datasets/student_data.csv")
print(student_datas)
# Out:
#       study_hours  attendance  sleep_hours  internet_usage  \
# 0               7          56            8               7
# 1               4          69            5               3
# 2              11          60            7               6
# 3               8          99            9               8
# 4               5          52            8               6
# ...           ...         ...          ...             ...
# 9995            2          58            9               7
# 9996            7          98            6               9
# 9997           10          44            8               5
# 9998           10          75            7               5
# 9999            2          70            6              11
#
#       assignments_completed  previous_score  exam_score placement_status
# 0                        10              62      100.00           Placed
# 1                         8              56      100.00           Placed
# ...

# %%
nd = pd.read_csv("datasets/netflix.csv")
print(nd.head(2))         #head() => First five return, give paramters for custom no of rows
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...

# %%
print(nd.tail(3))  #last five is tail and argument is custom no as we want
# Out:
#      show_id   type       title         director  \
# 8804   s8805  Movie  Zombieland  Ruben Fleischer
# 8805   s8806  Movie        Zoom     Peter Hewitt
# 8806   s8807  Movie      Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#             date_added  release_year rating duration  \
# 8804  November 1, 2019          2009      R   88 min
# 8805  January 11, 2020          2006     PG   88 min
# 8806     March 2, 2019          2015  TV-14  111 min
#
#                                            listed_in  \
# 8804                         Comedies, Horror Movies
# 8805              Children & Family Movies, Comedies
# 8806  Dramas, International Movies, Music & Musicals
#
# ...

# %%
print(nd.shape)
print(nd.columns)
# Out:
# (8807, 12)
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='str')
